# %% [markdown]
# # Problem 1
# Kullanıcıdan aldığı ürün bilgisini (ad, fiyat) urunler.txt dosyasına kayıt eden fonksiyonu yazınız.

# %%
# 1.Problemin Çözümünü Buraya Yazınız

def urun_kaydet():
    while True:
        urun_ad = input("Ürün adını giriniz (Çıkmak için q tuşuna basınız): ")
        if urun_ad=="q":
            break

        try:
            urun_fiyat =float(input("Ürün fiyatını giriniz: "))
        except ValueError:
            print("Geçersiz fiyat girdiniz. Tekrar deneyin.")
            continue

        with open("urunler.txt", "a") as f :
            f.write(f"{urun_ad} {urun_fiyat:.2f}\n")

        print(f"{urun_ad} ürünü {urun_fiyat:.2f} fiyatı ile kaydedildi.")

urun_kaydet()
# Out:
# Çikolata ürünü 5.00 fiyatı ile kaydedildi.
# Kalem ürünü 15.00 fiyatı ile kaydedildi.
# Ekmek ürünü 5.00 fiyatı ile kaydedildi.

# %% [markdown]
# # Problem 2
# 1.problemde oluşturulan text dosyası içerisinde kullanıcıdan alacağımız eski kelime isimli değişkene atadığımız
# ve değiştirilmesini istediğimiz kelimemizi yerini alıcak olan yeni kelime isimli değişkene atayın. Belirlenen kelimeleri text dosyasında değiştiren fonksiyonu yazınız.

# %%
# 2.Problemin Çözümünü Buraya Yazınız

def kelime_degistir(dosya_adi, eski_kelime, yeni_kelime):
    with open(dosya_adi, "r") as dosya:
        icerik = dosya.read()
    yeni_icerik = icerik.replace(eski_kelime, yeni_kelime)
    with open(dosya_adi, "w") as dosya:
        dosya.write(yeni_icerik)

kelime_degistir("urunler.txt", "Kalem", "Süt")

# %% [markdown]
# # Problem 3
# Vehicle sınıfının tüm değişkenlerini ve yöntemlerini devralacak bir alt sınıf olarak Bus sınıfı oluşturunuz.
#
#
#
# ```
# Output
# > Name: School Volvo Speed: 180 Mileage: 12
# ```

# %%
# 3.Problemin Çözümünü Buraya Yazınız

class Vehicle:
    def __init__(self, name, speed, mileage):
        self.name = name
        self.speed = speed
        self.mileage = mileage

class Bus(Vehicle):
    pass

bus = Bus("School Volvo", 180, 12)
print("Name:", bus.name, "Speed:", bus.speed, "Mileage:", bus.mileage)
# Out:
# Name: School Volvo Speed: 180 Mileage: 12
